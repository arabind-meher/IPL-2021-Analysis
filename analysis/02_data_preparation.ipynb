# %% [markdown]
# # Data Preparation
# ---

# %%
import re
from datetime import datetime

import numpy as np
import pandas as pd

# %% [markdown]
# ## Reading Data

# %%
# path
path = '../dataset/raw/Match 01 (MI vs RCB) 2021-04-09.csv'

# %%
# reading data
match = pd.read_csv(path)
match.head()
# Out:
#         inning    batting_team                 bowling_team  ball non_striker  \
# 0  1st innings  Mumbai Indians  Royal Challengers Bangalore   0.1     CA Lynn
# 1  1st innings  Mumbai Indians  Royal Challengers Bangalore   0.2     CA Lynn
# 2  1st innings  Mumbai Indians  Royal Challengers Bangalore   0.3     CA Lynn
# 3  1st innings  Mumbai Indians  Royal Challengers Bangalore   0.4     CA Lynn
# 4  1st innings  Mumbai Indians  Royal Challengers Bangalore   0.5     CA Lynn
#
#      batsman          bowler  extra_runs  batsman_run  total_runs  ...  \
# 0  RG Sharma  Mohammed Siraj           0            2           2  ...
# 1  RG Sharma  Mohammed Siraj           0            0           0  ...
# 2  RG Sharma  Mohammed Siraj           0            0           0  ...
# 3  RG Sharma  Mohammed Siraj           0            2           2  ...
# 4  RG Sharma  Mohammed Siraj           0            0           0  ...
#
#   elimination_kind fielders_caught            match_name  \
# 0              NaN             NaN  MI vs RCB 2021-04-09
# 1              NaN             NaN  MI vs RCB 2021-04-09
# 2              NaN             NaN  MI vs RCB 2021-04-09
# 3              NaN             NaN  MI vs RCB 2021-04-09
# 4              NaN             NaN  MI vs RCB 2021-04-09
#
#                umpires_1    umpires_2 player_of_match  \
# 0  KN Ananthapadmanabhan  Nitin Menon        HV Patel
# 1  KN Ananthapadmanabhan  Nitin Menon        HV Patel
# 2  KN Ananthapadmanabhan  Nitin Menon        HV Patel
# 3  KN Ananthapadmanabhan  Nitin Menon        HV Patel
# 4  KN Ananthapadmanabhan  Nitin Menon        HV Patel
#
#                         winner     city  \
# 0  Royal Challengers Bangalore  Chennai
# 1  Royal Challengers Bangalore  Chennai
# 2  Royal Challengers Bangalore  Chennai
# 3  Royal Challengers Bangalore  Chennai
# 4  Royal Challengers Bangalore  Chennai
#
#                                       venue       dates
# 0  MA Chidambaram Stadium, Chepauk, Chennai  2021-04-09
# 1  MA Chidambaram Stadium, Chepauk, Chennai  2021-04-09
# 2  MA Chidambaram Stadium, Chepauk, Chennai  2021-04-09
# 3  MA Chidambaram Stadium, Chepauk, Chennai  2021-04-09
# 4  MA Chidambaram Stadium, Chepauk, Chennai  2021-04-09
#
# [5 rows x 22 columns]

# %%
# analysing data
match.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   inning            250 non-null    object
#  1   batting_team      250 non-null    object
#  2   bowling_team      250 non-null    object
#  3   ball              250 non-null    float64
#  4   non_striker       250 non-null    object
#  5   batsman           250 non-null    object
#  6   bowler            250 non-null    object
#  7   extra_runs        250 non-null    int64
#  8   batsman_run       250 non-null    int64
#  9   total_runs        250 non-null    int64
#  10  extras            12 non-null     object
#  11  player_out        17 non-null     object
#  12  elimination_kind  17 non-null     object
#  13  fielders_caught   7 non-null      object
#  14  match_name        250 non-null    object
#  15  umpires_1         250 non-null    object
#  16  umpires_2         250 non-null    object
#  17  player_of_match   250 non-null    object
#  18  winner            250 non-null    object
#  19  city              250 non-null    object
#  20  venue             250 non-null    object
#  21  dates             250 non-null    object
# dtypes: float64(1), int64(3), object(18)
# memory usage: 290.7 KB

# %% [markdown]
# ## Cleaning Data

# %%
# storing single use data in variable
match_data = dict(
    match_no = int(path[21:23]),
    date = match['dates'].astype('datetime64').dt.strftime('%d %B %Y')[0],
    day = match['dates'].astype('datetime64').dt.strftime('%A')[0],
    team_1 = re.split(r'[ (.)]', path)[5],
    team_2 = re.split(r'[ (.)]', path)[7],
    umpire_1 = match.loc[:, 'umpires_1'][0],
    umpire_2 = match.loc[:, 'umpires_2'][0],
    player_of_match = match.loc[:, 'player_of_match'][0],
    winner = match.loc[:, 'winner'][0],
    city = match.loc[:, 'city'][0],
    venue = match.loc[:, 'venue'][0])

match_data
# Out:
# {'match_no': 1,
#  'date': '09 April 2021',
#  'day': 'Friday',
#  'team_1': 'MI',
#  'team_2': 'RCB',
#  'umpire_1': 'KN Ananthapadmanabhan',
#  'umpire_2': 'Nitin Menon',
#  'player_of_match': 'HV Patel',
#  'winner': 'Royal Challengers Bangalore',
#  'city': 'Chennai',
#  'venue': 'MA Chidambaram Stadium, Chepauk, Chennai'}

# %%
# dropping single data column
match.drop(
    ['match_name', 'umpires_1', 'umpires_2', 'player_of_match', 'winner', 'city', 'venue', 'dates'],
    axis=1, inplace=True)

# %%
# replacing 'N/A' with '0'
match.fillna(0, inplace=True)

# %%
# changing datatypes
match = match.astype({
    'inning': 'category',
    'batting_team': 'category',
    'bowling_team': 'category',
    'ball': 'float32',
    'non_striker': 'category',
    'batsman': 'category',
    'bowler': 'category',
    'extra_runs': 'int8',
    'batsman_run': 'int8',
    'total_runs': 'int8'
})

# %%
match.head()
# Out:
#         inning    batting_team                 bowling_team  ball non_striker  \
# 0  1st innings  Mumbai Indians  Royal Challengers Bangalore   0.1     CA Lynn
# 1  1st innings  Mumbai Indians  Royal Challengers Bangalore   0.2     CA Lynn
# 2  1st innings  Mumbai Indians  Royal Challengers Bangalore   0.3     CA Lynn
# 3  1st innings  Mumbai Indians  Royal Challengers Bangalore   0.4     CA Lynn
# 4  1st innings  Mumbai Indians  Royal Challengers Bangalore   0.5     CA Lynn
#
#      batsman          bowler  extra_runs  batsman_run  total_runs extras  \
# 0  RG Sharma  Mohammed Siraj           0            2           2      0
# 1  RG Sharma  Mohammed Siraj           0            0           0      0
# 2  RG Sharma  Mohammed Siraj           0            0           0      0
# 3  RG Sharma  Mohammed Siraj           0            2           2      0
# 4  RG Sharma  Mohammed Siraj           0            0           0      0
#
#   player_out elimination_kind fielders_caught
# 0          0                0               0
# 1          0                0               0
# 2          0                0               0
# 3          0                0               0
# 4          0                0               0

# %%
# analysing data
match.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   inning            250 non-null    category
#  1   batting_team      250 non-null    category
#  2   bowling_team      250 non-null    category
#  3   ball              250 non-null    float32
#  4   non_striker       250 non-null    category
#  5   batsman           250 non-null    category
#  6   bowler            250 non-null    category
#  7   extra_runs        250 non-null    int8
#  8   batsman_run       250 non-null    int8
#  9   total_runs        250 non-null    int8
#  10  extras            250 non-null    object
#  11  player_out        250 non-null    object
#  12  elimination_kind  250 non-null    object
#  13  fielders_caught   250 non-null    object
# dtypes: category(6), float32(1), int8(3), object(4)
# memory usage: 41.7 KB

# %% [markdown]
# ---
